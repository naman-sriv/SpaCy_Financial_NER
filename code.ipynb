# %% [markdown]
# Import Libraries

# %%
import spacy
import pandas as pd
from spacy import displacy

# %% [markdown]
# Import Data

# %%
df = pd.read_csv('securities.csv')

# %%
df.head(10)
# Out:
#   Ticker symbol             Security SEC filings             GICS Sector  \
# 0           MMM           3M Company     reports             Industrials
# 1           ABT  Abbott Laboratories     reports             Health Care
# 2          ABBV               AbbVie     reports             Health Care
# 3           ACN        Accenture plc     reports  Information Technology
# 4          ATVI  Activision Blizzard     reports  Information Technology
# 5           AYI    Acuity Brands Inc     reports             Industrials
# 6          ADBE    Adobe Systems Inc     reports  Information Technology
# 7           AAP   Advance Auto Parts     reports  Consumer Discretionary
# 8           AES             AES Corp     reports               Utilities
# 9           AET            Aetna Inc     reports             Health Care
#
#                               GICS Sub Industry   Address of Headquarters  \
# 0                      Industrial Conglomerates       St. Paul, Minnesota
# 1                         Health Care Equipment   North Chicago, Illinois
# 2                               Pharmaceuticals   North Chicago, Illinois
# 3                IT Consulting & Other Services           Dublin, Ireland
# 4                   Home Entertainment Software  Santa Monica, California
# 5             Electrical Components & Equipment          Atlanta, Georgia
# 6                          Application Software      San Jose, California
# 7                             Automotive Retail         Roanoke, Virginia
# 8  Independent Power Producers & Energy Traders       Arlington, Virginia
# 9                           Managed Health Care     Hartford, Connecticut
#
#   Date first added      CIK
# 0              NaN    66740
# 1       1964-03-31     1800
# 2       2012-12-31  1551152
# 3       2011-07-06  1467373
# 4       2015-08-31   718877
# 5       2016-05-03  1144215
# 6       1997-05-05   796343
# 7       2015-07-09  1158449
# 8              NaN   874761
# 9       1976-06-30  1122304

# %%
symbols = df['Ticker symbol'].tolist()
securities = df['Security'].tolist()
companies = []

# %%
for security in securities:
    companies.append(str(security).split()[0])
# Out:
# 2020

# %%
nlp = spacy.blank('en')
ruler = nlp.add_pipe("entity_ruler")
letters = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"

patterns = []
for symbol in symbols:
    patterns.append({"label": "STOCK", "pattern": symbol})
    for l in letters:
        patterns.append({"label": "STOCK", "pattern": symbol+f".{l}"})
for company in companies:
    patterns.append({"label": "COMPANY", "pattern": company})

ruler.add_patterns(patterns)

# %%
with open('text.txt','r') as f:
    text = f.read()

# %%
doc = nlp(text)

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Microsoft COMPANY
# MSFT.O STOCK
# Apple COMPANY
# AAPL.O STOCK
# Microsoft COMPANY
# Apple COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Apple COMPANY
# Microsoft COMPANY
# Alphabet COMPANY
# GOOGL.O STOCK
# Amazon.com COMPANY
# AMZN.O STOCK
# Oracle COMPANY
# ORCL.N STOCK
# Facebook COMPANY
# Microsoft COMPANY
# Apple COMPANY
# Microsoft COMPANY
# Apple COMPANY
# The COMPANY
# Microsoft COMPANY
# Microsoft COMPANY
# Apple COMPANY
# U.S. COMPANY
# Microsoft COMPANY
# Apple COMPANY

# %%
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">NEW YORK, Jan 24 (Reuters) -
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
# 's (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MSFT.O
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STOCK</span>
# </mark>
# ), opens new tab stock market value crossed the $3 trillion milestone for the first time on Wednesday, retaining its place as the world's second most valuable company, just behind
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AAPL.O
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STOCK</span>
# </mark>
# ), opens new tab.<br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  shares have been vying for the top spot as the most capitalized stock on Wall Street since the start of the year, with the iPhone maker briefly losing its crown to the software giant earlier in January.<br>Shares of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  hit a record high of $405.63, up 1.7%, enabling it to breach the $3 trillion market capitalization level. But it later closed at $402.56, valuing
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  at $2.99 trillion, just below the threshold price of $403.65 that would have kept it above $3 trillion.<br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
# 's shares pared earlier gains and closed down 0.35% at $194.50, giving it a market value of $3 trillion, according to LSEG data.<br>Backed by its investment in ChatGPT maker OpenAI,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  is widely seen as a frontrunner in the race for market dominance in the rollout of generative artificial intelligence (AI) among other tech heavyweights, including Google owner
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alphabet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GOOGL.O
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STOCK</span>
# </mark>
# ), opens new tab,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AMZN.O
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STOCK</span>
# </mark>
# ), opens new tab,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Oracle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ORCL.N
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STOCK</span>
# </mark>
# ), opens new tab, and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Facebook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  owner Meta Platforms (META.O), opens new tab.<br>Using OpenAI's technology,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
#  has rolled out newer versions of its flagship productivity software products as well as its Bing search engine, which is expected to better compete with Google's dominant search offering.<br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
# , on the other hand, is facing slowing demand for its iPhones, particularly in China, where the company is offering customers rare discounts to boost sales amid stiff competition from homegrown rivals such as Huawei Technologies (HWT.UL).<br>&quot;I think it's AI optimism for
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COMPANY</span>
# </mark>
# ,&quot; said Stifel analyst Brad Reback, adding that
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     App
