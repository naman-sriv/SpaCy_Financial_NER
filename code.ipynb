# %%
import spacy
import seaborn as sns
import gensim
import nltk

from spacy import displacy
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\naman\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))

# %%
nlp = spacy.load("en_core_web_sm")

# %%
with open("text.txt","r") as f:
    text = f.read()

# %%
text.replace("\n","")
# Out:
# 'The CNIL said Amazon France Logistique, which manages warehouses, recorded data captured by workers\' handheld scanners.It found Amazon tracked activity so precisely that it led to workers having to potentially justify each break.Amazon said it strongly disagreed with the CNIL\'s findings and called them "factually incorrect".France\'s data protection agency investigated Amazon warehouses following complaints by employees as well as media coverage of conditions.It outlined a number of areas where it found Amazon had breached General Data Protection Regulation (GDPR).This included a system with three alerts in place to monitor employee activity, which the CNIL ruled to be illegal.One alert triggered if an item was scanned too quickly or less than 1.25 seconds after scanning a previous item, increasing the risk of error.Another signalled breaks of 10 minutes or more, while a third tracked breaks between one and 10 minutes.The CNIL also questioned why Amazon needed to keep workers\' data for 31 days.Responding to the findings an Amazon spokesperson said: "We strongly disagree with the CNIL\'s conclusions which are factually incorrect and we reserve the right to file an appeal."Warehouse management systems are industry standard and are necessary for ensuring the safety, quality, and efficiency of operations and to track the storage of inventory and processing of packages on time and in line with customer expectations."'

# %%
doc = nlp(text)

# %%
sentences = []

for sent in doc.sents:
    sentences.append(str(sent))


sentences = [sentence.split() for sentence in sentences]

for i in range(len(sentences)):
    sentences[i] =[word for word in sentences[i] if word not in stop_words]

# %%
# # Extract lemmatized tokens
# lemmatized_tokens = [token.lemma_ for token in doc if not token.is_stop]
 
# # Join the lemmatized tokens into a sentence
# lemmatized_text = ' '.join(lemmatized_tokens)
 
# # Print the original and lemmatized text
# print("Original Text:", text)

# %%
# print("Lemmatized Text:", lemmatized_text)

# %%
sentences
# Out:
# [['The',
#   'CNIL',
#   'said',
#   'Amazon',
#   'France',
#   'Logistique,',
#   'manages',
#   'warehouses,',
#   'recorded',
#   'data',
#   'captured',
#   "workers'",
#   'handheld',
#   'scanners.'],
#  ['It',
#   'found',
#   'Amazon',
#   'tracked',
#   'activity',
#   'precisely',
#   'led',
#   'workers',
#   'potentially',
#   'justify',
#   'break.'],
#  ['Amazon',
#   'said',
#   'strongly',
#   'disagreed',
#   "CNIL's",
#   'findings',
#   'called',
#   '"factually',
#   'incorrect".'],
#  ["France's",
#   'data',
#   'protection',
#   'agency',
#   'investigated',
#   'Amazon',
#   'warehouses',
#   'following',
#   'complaints',
#   'employees',
#   'well',
#   'media',
#   'coverage',
#   'conditions.'],
#  ['It',
#   'outlined',
#   'number',
#   'areas',
#   'found',
#   'Amazon',
#   'breached',
#   'General',
#   'Data',
#   'Protection',
#   'Regulation',
#   '(GDPR).'],
#  ['This',
#   'included',
#   'system',
#   'three',
#   'alerts',
#   'place',
#   'monitor',
#   'employee',
#   'activity,',
#   'CNIL',
#   'ruled',
#   'illegal.'],
#  ['One',
#   'alert',
#   'triggered',
#   'item',
#   'scanned',
#   'quickly',
#   'less',
#   '1.25',
#   'seconds',
#   'scanning',
#   'previous',
#   'item,',
#   'increasing',
#   'risk',
#   'error.'],
#  ['Another',
#   'signalled',
#   'breaks',
#   '10',
#   'minutes',
#   'more,',
#   'third',
#   'tracked',
#   'breaks',
#   'one',
#   '10',
#   'minutes.'],
#  ['The',
#   'CNIL',
#   'also',
#   'questioned',
#   'Amazon',
#   'needed',
#   'keep',
#   "workers'",
#   'data',
#   '31',
#   'days.'],
#  ['Responding',
#   'findings',
#   'Amazon',
#   'spokesperson',
#   'said:',
#   '"We',
#   'strongly',
#   'disagree',
#   "CNIL's",
#   'conclusions',
#   'factually',
#   'incorrect',
#   'reserve',
#   'right',
#   'file',
#   'appeal.'],
#  ['"Warehouse',
#   'management',
#   'systems',
#   'industry',
#   'standard',
#   'necessary',
#   'ensuring',
#   'safety,',
#   'quality,',
#   'efficiency',
#   'operations',
#   'track',
#   'storage',
#   'inventory',
#   'processing',
#   'packages',
#   'time',
#   'line',
#   'customer',
#   'expectations."']]

# %%
model = gensim.models.Word2Vec(sentences, min_count=1, vector_size=100)

# %%
for index, word in enumerate(model.wv.index_to_key):
    print(f"word #{index}/{len(model.wv.index_to_key)} is {word}")
# Out:
# word #0/125 is Amazon
# word #1/125 is CNIL
# word #2/125 is data
# word #3/125 is The
# word #4/125 is workers'
# word #5/125 is strongly
# word #6/125 is CNIL's
# word #7/125 is tracked
# word #8/125 is found
# word #9/125 is It
# word #10/125 is findings
# word #11/125 is breaks
# word #12/125 is 10
# word #13/125 is said
# word #14/125 is areas
# word #15/125 is conditions.
# word #16/125 is coverage
# word #17/125 is media
# word #18/125 is well
# word #19/125 is employees
# word #20/125 is outlined
# word #21/125 is number
# word #22/125 is Regulation
# word #23/125 is breached
# word #24/125 is General
# word #25/125 is Data
# word #26/125 is Protection
# word #27/125 is following
# word #28/125 is (GDPR).
# word #29/125 is This
# word #30/125 is included
# word #31/125 is system
# word #32/125 is three
# word #33/125 is alerts
# word #34/125 is place
# word #35/125 is monitor
# word #36/125 is complaints
# word #37/125 is incorrect".
# word #38/125 is warehouses
# word #39/125 is led
# word #40/125 is France
# word #41/125 is Logistique,
# word #42/125 is manages
# word #43/125 is warehouses,
# word #44/125 is recorded
# word #45/125 is captured
# word #46/125 is handheld
# word #47/125 is scanners.
# word #48/125 is activity
# word #49/125 is precisely
# word #50/125 is workers
# word #51/125 is investigated
# word #52/125 is potentially
# word #53/125 is justify
# word #54/125 is break.
# word #55/125 is disagreed
# word #56/125 is called
# word #57/125 is "factually
# word #58/125 is activity,
# word #59/125 is France's
# word #60/125 is protection
# word #61/125 is agency
# word #62/125 is employee
# word #63/125 is expectations."
# word #64/125 is ruled
# word #65/125 is spokesperson
# word #66/125 is "We
# word #67/125 is disagree
# word #68/125 is conclusions
# word #69/125 is factually
# word #70/125 is incorrect
# word #71/125 is reserve
# word #72/125 is right
# word #73/125 is file
# word #74/125 is appeal.
# word #75/125 is "Warehouse
# word #76/125 is management
# word #77/125 is systems
# word #78/125 is industry
# word #79/125 is standard
# word #80/125 is necessary
# word #81/125 is ensuring
# word #82/125 is safety,
# word #83/125 is quality,
# word #84/125 is efficiency
# word #85/125 is operations
# word #86/125 is track
# word #87/125 is storage
# word #88/125 is inventory
# word #89/125 is processing
# word #90/125 is packages
# word #91/125 is time
# word #92/125 is line
# word #93/125 is said:
# word #94/125 is Responding
# word #95/125 is customer
# word #96/125 is days.
# word #97/125 is One
# word #98/125 is alert
# word #99/125 is triggered
# word #100/125 is item
# word #101/125 is scanned
# word #102/125 is quickly
# word #103/125 is less
# word #104/125 is 1.25
# word #105/125 is seconds
# word #106/125 is scanning
# word #107/125 is previous
# word #108/125 is item,
# word #109/125 is increasing
# word #110/125 is risk
# word #111/125 is error.
# word #112/125 is Another
# word #113/125 is signalled
# word #114/125 is minutes
# word #115/125 is more,
# word #116/125 is third
# word #117/125 is one
# word #118/125 is minutes.
# word #119/125 is also
# word #120/125 is questioned
# word #121/125 is needed
# word #122/125 is keep
# word #123/125 is 31
# word #124/125 is illegal.

# %%
displacy.render(doc,style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNIL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  said
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon France Logistique
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , which manages warehouses, recorded data captured by workers' handheld scanners.<br><br>It found
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  tracked activity so precisely that it led to workers having to potentially justify each break.<br><br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  said it strongly disagreed with the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNIL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's findings and called them &quot;factually incorrect&quot;.<br><br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     France
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's data protection agency investigated
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  warehouses following complaints by employees as well as media coverage of conditions.<br><br>It outlined a number of areas where it found
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  had breached
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     General Data Protection Regulation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (GDPR).<br><br>This included a system with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  alerts in place to monitor employee activity, which the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNIL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  ruled to be illegal.<br><br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     One
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  alert triggered if an item was scanned too quickly or
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     less than 1.25 seconds
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  after scanning a previous item, increasing the risk of error.<br><br>Another signalled breaks of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10 minutes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  or more, while a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     third
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  tracked breaks
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     between one and 10 minutes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# .<br><br>The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNIL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  also questioned why
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  needed to keep workers' data for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     31 days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .<br><br>Responding to the findings an
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  spokesperson said: &quot;We strongly disagree with the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNIL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's conclusions which are factually incorrect and we reserve the right to file an appeal.<br><br>&quot;Warehouse management systems are industry standard and are necessary for ensuring the safety, quality, and efficiency of operations and to track the storage of inventory and processing of packages on time and in line with customer expectations.&quot;</div></span>

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# CNIL ORG
# Amazon France Logistique ORG
# Amazon ORG
# Amazon ORG
# CNIL ORG
# France GPE
# Amazon ORG
# Amazon ORG
# General Data Protection Regulation ORG
# three CARDINAL
# CNIL ORG
# One CARDINAL
# less than 1.25 seconds TIME
# 10 minutes TIME
# third ORDINAL
# between one and 10 minutes CARDINAL
# CNIL ORG
# Amazon ORG
# 31 days DATE
# Amazon ORG
# CNIL ORG
